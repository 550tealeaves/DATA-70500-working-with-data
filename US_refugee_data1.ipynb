# %% [markdown]
# <a href="https://colab.research.google.com/github/550tealeaves/DATA-70500-working-with-data/blob/main/US_refugee_data1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib

# %%
# import pyodide_http #able to grab http links online
# pyodide_http.patch_all() #makes emulator work - not related to pandas

#assign url to variable
url = 'https://raw.githubusercontent.com/GC-DRI/DRI24/main/uploads/pandas/refugee-arrivals-by-destination.csv'

#convert csv data into a dataframe
# 1. create data frame called refugee_df
# 2. set dataframe equal to pd.read_csv
# 3. Take the link that's assigned to url and read it
# 4. Need parameters - source (url), delimiter (","), encoding (UTF-8 - lets computer know how to read what it's seeing)
refugee_df = pd.read_csv(url, delimiter=",", encoding='utf-8')

# %% [markdown]
# # **Data exploration**
# ## Display the Dataframe
# To display the DataFrame, we can run a cell with the variable name of the DataFrame:

# %%
refugee_df
# Out:
#         year       origin dest_state  dest_city  arrivals
# 0       2005  Afghanistan    Alabama     Mobile         0
# 1       2006  Afghanistan    Alabama     Mobile         0
# 2       2007  Afghanistan    Alabama     Mobile         0
# 3       2008  Afghanistan    Alabama     Mobile         0
# 4       2009  Afghanistan    Alabama     Mobile         5
# ...      ...          ...        ...        ...       ...
# 121240  2011      Vietnam  Wisconsin  Milwaukee         0
# 121241  2012      Vietnam  Wisconsin  Milwaukee         4
# 121242  2013      Vietnam  Wisconsin  Milwaukee         2
# 121243  2014      Vietnam  Wisconsin  Milwaukee         0
# 121244  2015      Vietnam  Wisconsin  Milwaukee         0
#
# [121245 rows x 5 columns]

# %%
# see first 3 rows
refugee_df.head(3)
# Out:
#    year       origin dest_state dest_city  arrivals
# 0  2005  Afghanistan    Alabama    Mobile         0
# 1  2006  Afghanistan    Alabama    Mobile         0
# 2  2007  Afghanistan    Alabama    Mobile         0

# %%
refugee_df[:3] # basic python that does same as .head(3)
# Out:
#    year       origin dest_state dest_city  arrivals
# 0  2005  Afghanistan    Alabama    Mobile         0
# 1  2006  Afghanistan    Alabama    Mobile         0
# 2  2007  Afghanistan    Alabama    Mobile         0

# %%
refugee_df.tail(10) #shows last 10 rows
# Out:
#         year   origin dest_state  dest_city  arrivals
# 121235  2006  Vietnam  Wisconsin  Milwaukee         5
# 121236  2007  Vietnam  Wisconsin  Milwaukee        18
# 121237  2008  Vietnam  Wisconsin  Milwaukee        12
# 121238  2009  Vietnam  Wisconsin  Milwaukee         4
# 121239  2010  Vietnam  Wisconsin  Milwaukee         7
# 121240  2011  Vietnam  Wisconsin  Milwaukee         0
# 121241  2012  Vietnam  Wisconsin  Milwaukee         4
# 121242  2013  Vietnam  Wisconsin  Milwaukee         2
# 121243  2014  Vietnam  Wisconsin  Milwaukee         0
# 121244  2015  Vietnam  Wisconsin  Milwaukee         0

# %%
refugee_df[-10:] #basic python slice that does same as .tail(10)
# Out:
#         year   origin dest_state  dest_city  arrivals
# 121235  2006  Vietnam  Wisconsin  Milwaukee         5
# 121236  2007  Vietnam  Wisconsin  Milwaukee        18
# 121237  2008  Vietnam  Wisconsin  Milwaukee        12
# 121238  2009  Vietnam  Wisconsin  Milwaukee         4
# 121239  2010  Vietnam  Wisconsin  Milwaukee         7
# 121240  2011  Vietnam  Wisconsin  Milwaukee         0
# 121241  2012  Vietnam  Wisconsin  Milwaukee         4
# 121242  2013  Vietnam  Wisconsin  Milwaukee         2
# 121243  2014  Vietnam  Wisconsin  Milwaukee         0
# 121244  2015  Vietnam  Wisconsin  Milwaukee         0

# %%
# .sample() method to get random sample for testing
refugee_df.sample(15)
# Out:
#         year                    origin     dest_state         dest_city  \
# 111731  2006                    Jordan       Virginia      Harrisonburg
# 55413   2008                   Somalia  Massachusetts       Charlestown
# 24256   2014                     Burma        Florida  North Palm Beach
# 18      2008                     Burma        Alabama            Auburn
# 54782   2015                    Russia  Massachusetts            Boston
# 105994  2011        Sri Lanka (Ceylon)          Texas       San Antonio
# 87684   2005                    Russia           Ohio             Parma
# 8556    2011                      Iran     California           Esparto
# 66845   2011                    Rwanda       Missouri       Saint Louis
# 116634  2014                Kyrgyzstan     Washington            Renton
# 100598  2005                     Burma          Texas          Benbrook
# 88646   2010                   Vietnam           Ohio          Columbus
# ...

# %%
refugee_df.head(9)
# Out:
#    year       origin dest_state dest_city  arrivals
# 0  2005  Afghanistan    Alabama    Mobile         0
# 1  2006  Afghanistan    Alabama    Mobile         0
# 2  2007  Afghanistan    Alabama    Mobile         0
# 3  2008  Afghanistan    Alabama    Mobile         0
# 4  2009  Afghanistan    Alabama    Mobile         5
# 5  2010  Afghanistan    Alabama    Mobile         8
# 6  2011  Afghanistan    Alabama    Mobile         5
# 7  2012  Afghanistan    Alabama    Mobile         7
# 8  2013  Afghanistan    Alabama    Mobile         9

# %%
refugee_df[:9]
# Out:
#    year       origin dest_state dest_city  arrivals
# 0  2005  Afghanistan    Alabama    Mobile         0
# 1  2006  Afghanistan    Alabama    Mobile         0
# 2  2007  Afghanistan    Alabama    Mobile         0
# 3  2008  Afghanistan    Alabama    Mobile         0
# 4  2009  Afghanistan    Alabama    Mobile         5
# 5  2010  Afghanistan    Alabama    Mobile         8
# 6  2011  Afghanistan    Alabama    Mobile         5
# 7  2012  Afghanistan    Alabama    Mobile         7
# 8  2013  Afghanistan    Alabama    Mobile         9

# %%
# see last 5 rows
refugee_df.tail()
# Out:
#         year   origin dest_state  dest_city  arrivals
# 121240  2011  Vietnam  Wisconsin  Milwaukee         0
# 121241  2012  Vietnam  Wisconsin  Milwaukee         4
# 121242  2013  Vietnam  Wisconsin  Milwaukee         2
# 121243  2014  Vietnam  Wisconsin  Milwaukee         0
# 121244  2015  Vietnam  Wisconsin  Milwaukee         0

# %%
refugee_df[-5:]
# Out:
#         year   origin dest_state  dest_city  arrivals
# 121240  2011  Vietnam  Wisconsin  Milwaukee         0
# 121241  2012  Vietnam  Wisconsin  Milwaukee         4
# 121242  2013  Vietnam  Wisconsin  Milwaukee         2
# 121243  2014  Vietnam  Wisconsin  Milwaukee         0
# 121244  2015  Vietnam  Wisconsin  Milwaukee         0

# %%
# .sample() method gives you a random sample of data for testing
refugee_df.sample(10)
# Out:
#         year                    origin    dest_state      dest_city  arrivals
# 16969   2009                   Ukraine    California       El Cajon         0
# 10204   2009                      Iran    California  Scotts Valley         0
# 25480   2006                      Cuba       Florida   Kenneth City         0
# 99980   2014                   Ukraine     Tennessee       Ooltewah         0
# 101375  2012  Central African Republic         Texas         Austin         0
# 70979   2009                      Iran    New Jersey     Mont Clair         0
# 100498  2015                    Bhutan         Texas    San Antonio        45
# 14014   2013                      Laos    California         Fresno         0
# 108135  2007                   Somalia          Utah    West Jordan         1
# 96551   2006               Ivory Coast  Rhode Island     Providence         2

# %% [markdown]
# # **Basic Data Cleaning**
# - Convert data types (year from int to datetime)
# - Check for and remove duplicates

# %%
# get .info() method to get info about dataset and types
refugee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121245 entries, 0 to 121244
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        121245 non-null  int64
#  1   origin      121245 non-null  object
#  2   dest_state  121245 non-null  object
#  3   dest_city   121245 non-null  object
#  4   arrivals    121245 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 4.6+ MB

# %%
# target year col in dataframe and convert it from integer to date/time type
refugee_df['year'] = pd.to_datetime(refugee_df['year'], format="%Y")

# %%
#check datatypes to make sure conversion worked
refugee_df.dtypes
# Out:
# year          datetime64[ns]
# origin                object
# dest_state            object
# dest_city             object
# arrivals               int64
# dtype: object

# %%
#check for duplicate rows w/ .duplicated() method
# parameter keep=False - shows duplicated values
refugee_df[refugee_df.duplicated(keep=False)]
# Out:
#           year origin dest_state     dest_city  arrivals
# 13  2007-01-01  Burma    Alabama        Auburn         0
# 14  2008-01-01  Burma    Alabama        Auburn         0
# 15  2009-01-01  Burma    Alabama        Auburn         0
# 16  2010-01-01  Burma    Alabama        Auburn         0
# 17  2007-01-01  Burma    Alabama        Auburn         0
# 18  2008-01-01  Burma    Alabama        Auburn         0
# 19  2009-01-01  Burma    Alabama        Auburn         0
# 20  2010-01-01  Burma    Alabama        Auburn         0
# 155 2013-01-01   Cuba    Alabama  Russellville         0
# 156 2014-01-01   Cuba    Alabama  Russellville         0
# 157 2015-01-01   Cuba    Alabama  Russellville         0
# 158 2005-01-01   Cuba    Alabama      Theodore         0
# 159 2006-01-01   Cuba    Alabama      Theodore         0
# 160 2013-01-01   Cuba    Alabama  Russellville         0
# 161 2014-01-01   Cuba    Alabama  Russellville         0
# ...

# %%
# Use .drop_duplicates() method to remove duplicates
# Use keep='first' to keep the 1st instance of the duplicate of the last
refugee_df = refugee_df.drop_duplicates(keep='first')

# %%
# Run .duplicated() method to see if duplicates were removed
refugee_df[refugee_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [year, origin, dest_state, dest_city, arrivals]
# Index: []

# %% [markdown]
# # **Rename, select, drop, filter, and add columns**
# - Useful to create multiple dataframes so you have an original set that has everything, and you have other variants to do calculations on

# %%
# .columns shows all the columns
refugee_df.columns
# Out:
# Index(['year', 'origin', 'dest_state', 'dest_city', 'arrivals'], dtype='object')

# %%
# use .rename() method + columns= parameter to rename a column
refugee_df = refugee_df.rename(columns={'dest_state': 'state', 'dest_city':'city' })
refugee_df
# Out:
#              year       origin      state       city  arrivals
# 0      2005-01-01  Afghanistan    Alabama     Mobile         0
# 1      2006-01-01  Afghanistan    Alabama     Mobile         0
# 2      2007-01-01  Afghanistan    Alabama     Mobile         0
# 3      2008-01-01  Afghanistan    Alabama     Mobile         0
# 4      2009-01-01  Afghanistan    Alabama     Mobile         5
# ...           ...          ...        ...        ...       ...
# 121240 2011-01-01      Vietnam  Wisconsin  Milwaukee         0
# 121241 2012-01-01      Vietnam  Wisconsin  Milwaukee         4
# 121242 2013-01-01      Vietnam  Wisconsin  Milwaukee         2
# 121243 2014-01-01      Vietnam  Wisconsin  Milwaukee         0
# 121244 2015-01-01      Vietnam  Wisconsin  Milwaukee         0
#
# [121231 rows x 5 columns]

# %%
# to view data from 1 col - transforms series object into dataframe w/ 2 [[]]
refugee_df[['state']]
# Out:
#             state
# 0         Alabama
# 1         Alabama
# 2         Alabama
# 3         Alabama
# 4         Alabama
# ...           ...
# 121240  Wisconsin
# 121241  Wisconsin
# 121242  Wisconsin
# 121243  Wisconsin
# 121244  Wisconsin
#
# [121231 rows x 1 columns]

# %%
# view data from multiple cols by separating col names w/ comma
refugee_df[['state', 'city']]
# Out:
#             state       city
# 0         Alabama     Mobile
# 1         Alabama     Mobile
# 2         Alabama     Mobile
# 3         Alabama     Mobile
# 4         Alabama     Mobile
# ...           ...        ...
# 121240  Wisconsin  Milwaukee
# 121241  Wisconsin  Milwaukee
# 121242  Wisconsin  Milwaukee
# 121243  Wisconsin  Milwaukee
# 121244  Wisconsin  Milwaukee
#
# [121231 rows x 2 columns]

# %%
# 1 [] = seris object NOT dataframe and cannot handle multiple columns
refugee_df['state']
# Out:
# 0           Alabama
# 1           Alabama
# 2           Alabama
# 3           Alabama
# 4           Alabama
#             ...
# 121240    Wisconsin
# 121241    Wisconsin
# 121242    Wisconsin
# 121243    Wisconsin
# 121244    Wisconsin
# Name: state, Length: 121231, dtype: object

# %%
# Use .drop() method & col name to remove column
refugee_drop_city_df = refugee_df.drop(columns='city')
refugee_drop_city_df
# Out:
#              year       origin      state  arrivals
# 0      2005-01-01  Afghanistan    Alabama         0
# 1      2006-01-01  Afghanistan    Alabama         0
# 2      2007-01-01  Afghanistan    Alabama         0
# 3      2008-01-01  Afghanistan    Alabama         0
# 4      2009-01-01  Afghanistan    Alabama         5
# ...           ...          ...        ...       ...
# 121240 2011-01-01      Vietnam  Wisconsin         0
# 121241 2012-01-01      Vietnam  Wisconsin         4
# 121242 2013-01-01      Vietnam  Wisconsin         2
# 121243 2014-01-01      Vietnam  Wisconsin         0
# 121244 2015-01-01      Vietnam  Wisconsin         0
#
# [121231 rows x 4 columns]

# %%
# Filtering df similar to selecting columns
# type df name then [] & include a True/False condition
refugee_iraq_df = refugee_df[refugee_df['origin'] == 'Iraq']
refugee_iraq_df
# Out:
#              year origin      state        city  arrivals
# 267    2005-01-01   Iraq    Alabama  Birmingham         0
# 268    2006-01-01   Iraq    Alabama  Birmingham         0
# 269    2007-01-01   Iraq    Alabama  Birmingham         0
# 270    2008-01-01   Iraq    Alabama  Birmingham         6
# 271    2009-01-01   Iraq    Alabama  Birmingham         0
# ...           ...    ...        ...         ...       ...
# 120503 2011-01-01   Iraq  Wisconsin   Wauwatosa         0
# 120504 2012-01-01   Iraq  Wisconsin   Wauwatosa         0
# 120505 2013-01-01   Iraq  Wisconsin   Wauwatosa         2
# 120506 2014-01-01   Iraq  Wisconsin   Wauwatosa         0
# 120507 2015-01-01   Iraq  Wisconsin   Wauwatosa         6
#
# [18205 rows x 5 columns]

# %%
# to drop rows set to != (not equal) show all rows not equal to origin == Iraq
refugee_drop_iraq_df = refugee_df[refugee_df['origin'] != 'Iraq']
refugee_drop_iraq_df
# Out:
#              year       origin      state       city  arrivals
# 0      2005-01-01  Afghanistan    Alabama     Mobile         0
# 1      2006-01-01  Afghanistan    Alabama     Mobile         0
# 2      2007-01-01  Afghanistan    Alabama     Mobile         0
# 3      2008-01-01  Afghanistan    Alabama     Mobile         0
# 4      2009-01-01  Afghanistan    Alabama     Mobile         5
# ...           ...          ...        ...        ...       ...
# 121240 2011-01-01      Vietnam  Wisconsin  Milwaukee         0
# 121241 2012-01-01      Vietnam  Wisconsin  Milwaukee         4
# 121242 2013-01-01      Vietnam  Wisconsin  Milwaukee         2
# 121243 2014-01-01      Vietnam  Wisconsin  Milwaukee         0
# 121244 2015-01-01      Vietnam  Wisconsin  Milwaukee         0
#
# [103026 rows x 5 columns]

# %%
# Add columns - add the col name in brackets next to df
# assign that to mathematical or logical formula required
refugee_df['percent_total'] = (refugee_df['arrivals'] / refugee_df['arrivals'].sum())*100
refugee_df
# Out:
#              year       origin      state       city  arrivals  percent_total
# 0      2005-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 1      2006-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 2      2007-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 3      2008-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 4      2009-01-01  Afghanistan    Alabama     Mobile         5       0.000743
# ...           ...          ...        ...        ...       ...            ...
# 121240 2011-01-01      Vietnam  Wisconsin  Milwaukee         0       0.000000
# 121241 2012-01-01      Vietnam  Wisconsin  Milwaukee         4       0.000595
# 121242 2013-01-01      Vietnam  Wisconsin  Milwaukee         2       0.000297
# 121243 2014-01-01      Vietnam  Wisconsin  Milwaukee         0       0.000000
# 121244 2015-01-01      Vietnam  Wisconsin  Milwaukee         0       0.000000
#
# [121231 rows x 6 columns]

# %%
# Select year, origin, & arrivals columns
refugee_df[['year', 'origin', 'arrivals']]
# Out:
#              year       origin  arrivals
# 0      2005-01-01  Afghanistan         0
# 1      2006-01-01  Afghanistan         0
# 2      2007-01-01  Afghanistan         0
# 3      2008-01-01  Afghanistan         0
# 4      2009-01-01  Afghanistan         5
# ...           ...          ...       ...
# 121240 2011-01-01      Vietnam         0
# 121241 2012-01-01      Vietnam         4
# 121242 2013-01-01      Vietnam         2
# 121243 2014-01-01      Vietnam         0
# 121244 2015-01-01      Vietnam         0
#
# [121231 rows x 3 columns]

# %%
# drop all rows where origin is Vietnam
refugee_drop_vietnam_df = refugee_df[refugee_df['origin'] != 'Vietnam']
refugee_drop_vietnam_df
# Out:
#              year       origin      state       city  arrivals  percent_total
# 0      2005-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 1      2006-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 2      2007-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 3      2008-01-01  Afghanistan    Alabama     Mobile         0       0.000000
# 4      2009-01-01  Afghanistan    Alabama     Mobile         5       0.000743
# ...           ...          ...        ...        ...       ...            ...
# 121196 2011-01-01   Uzbekistan  Wisconsin  Milwaukee         0       0.000000
# 121197 2012-01-01   Uzbekistan  Wisconsin  Milwaukee         0       0.000000
# 121198 2013-01-01   Uzbekistan  Wisconsin  Milwaukee         0       0.000000
# 121199 2014-01-01   Uzbekistan  Wisconsin  Milwaukee         0       0.000000
# 121200 2015-01-01   Uzbekistan  Wisconsin  Milwaukee         0       0.000000
#
# [115698 rows x 6 columns]

# %%
# keep rows w/ arrival state is California
refugee_california_df = refugee_df[refugee_df['state'] == 'California']
refugee_california_df
# Out:
#             year       origin       state        city  arrivals  percent_total
# 3457  2005-01-01  Afghanistan  California     Alameda         1       0.000149
# 3458  2006-01-01  Afghanistan  California     Alameda         0       0.000000
# 3459  2007-01-01  Afghanistan  California     Alameda         0       0.000000
# 3460  2008-01-01  Afghanistan  California     Alameda         0       0.000000
# 3461  2009-01-01  Afghanistan  California     Alameda         0       0.000000
# ...          ...          ...         ...         ...       ...            ...
# 18896 2011-01-01     Zimbabwe  California  Sacramento         0       0.000000
# 18897 2012-01-01     Zimbabwe  California  Sacramento         2       0.000297
# 18898 2013-01-01     Zimbabwe  California  Sacramento         0       0.000000
# 18899 2014-01-01     Zimbabwe  California  Sacramento         0       0.000000
# 18900 2015-01-01     Zimbabwe  California  Sacramento         0       0.000000
#
# ...

# %% [markdown]
# # **Sort columns, groupby columns, and calculations**
# - Be mindful of when dataframe converts to series object
# - Series object (1D array) cannot do calculations that DataFrame (2D tabular structure) can
# - Use .to_frame() method & reset_index() method to convert series back to dataframe

# %%
# sort columns using .sort_values() method & by= (parameter) and col name
# example sorts dataframe by arrivals in descending order
refugee_df.sort_values(by='arrivals', ascending=False)
# Out:
#              year   origin       state        city  arrivals  percent_total
# 11359  2009-01-01     Iraq  California    El Cajon      2813       0.418279
# 8718   2008-01-01     Iran  California    Glendale      2025       0.301107
# 11360  2010-01-01     Iraq  California    El Cajon      1811       0.269286
# 8719   2009-01-01     Iran  California    Glendale      1722       0.256053
# 58761  2012-01-01     Iraq    Michigan  Southfield      1720       0.255755
# ...           ...      ...         ...         ...       ...            ...
# 46638  2011-01-01     Iraq       Maine    Rockport         0       0.000000
# 46637  2010-01-01     Iraq       Maine    Rockport         0       0.000000
# 46636  2009-01-01     Iraq       Maine    Rockport         0       0.000000
# 46635  2008-01-01     Iraq       Maine    Rockport         0       0.000000
# 121244 2015-01-01  Vietnam   Wisconsin   Milwaukee         0       0.000000
#
# [121231 rows x 6 columns]

# %%
# use .groupby() method to group data
# see breakdown of # arrivals by country of origin
refugee_df.groupby('origin')

# %%
# Groupby origin
# Summing # of arrivals from each country of origin
# Sort values in descending order
# Take the top 20 values
refugee_df.groupby('origin')['arrivals'].sum().sort_values(ascending=False)[:20]
# Out:
# origin
# Burma              151875
# Iraq               127326
# Bhutan              85316
# Somalia             71120
# Cuba                39946
# Iran                36683
# Dem. Rep. Congo     25493
# Russia              15656
# Eritrea             14645
# Sudan               12636
# Ukraine             11727
# Burundi             11152
# Vietnam             10769
# Liberia              9424
# Ethiopia             8487
# Afghanistan          6751
# Laos                 6609
# Moldova              4482
# Syria                2359
# Colombia             1956
# Name: arrivals, dtype: int64

# %%
# Covert series object into dataframe (series doesn't let us do calculations)
# Use to_frame & reset_index
ref_sum_df = refugee_df.groupby('origin')['arrivals'].sum().sort_values(ascending=False)[:20]
ref_sum_df = ref_sum_df.to_frame().reset_index() #converts from series to data frame & resets index
ref_sum_df
# Out:
#              origin  arrivals
# 0             Burma    151875
# 1              Iraq    127326
# 2            Bhutan     85316
# 3           Somalia     71120
# 4              Cuba     39946
# 5              Iran     36683
# 6   Dem. Rep. Congo     25493
# 7            Russia     15656
# 8           Eritrea     14645
# 9             Sudan     12636
# 10          Ukraine     11727
# 11          Burundi     11152
# 12          Vietnam     10769
# 13          Liberia      9424
# 14         Ethiopia      8487
# 15      Afghanistan      6751
# 16             Laos      6609
# 17          Moldova      4482
# 18            Syria      2359
# 19         Colombia      1956

# %% [markdown]
# # **Data Visualizations**
# ## Use .plot() method and kind= (parameter) to determine what plots to apply
# - Viz helps easily translate data insights to users
# - Can see patterns

# %%
# Create bar chart using .plot() method
# \n is  line break
ref_sum_df.plot(kind='bar', x='origin', y='arrivals', color='green', title='Total number of refugee arrivals in the U.S. \n by country of origin')
# Out:
# <Axes: title={'center': 'Total number of refugee arrivals in the U.S. \n by country of origin'}, xlabel='origin'>

# %% [markdown]
# Let’s unpack the command to better understand these results:
#
# - ref_sum_df: This is the variable we created in the previous lesson summing the number of refugee arrivals by country of origin, with the output showing the top twenty rows sorted by descending order
# - .plot(kind='bar', x= 'origin', y='arrivals', title='Total number of refugee arrivals in the U.S. \n by country of origin'):
# - - Here we are using the .plot() method to create a visualization, and we are specifying that we want a bar chart with the “kind=’bar’” parameter.
# - - We also specify the values for the x axis (orgin) and y axis (arrivals)
# - - We are also giving the chart a title with the “title='Total number of refugee arrivals in the U.S. \n by country of origin'” parameter.
# Note: By adding “\n” in the title text, we signify that the text that follows should be on a new line.
#
# # Pie Charts
# We can also visualize the data as a pie chart:

# %%
ref_sum_df.set_index('origin')[:10].plot(kind='pie', y='arrivals',
                                         title='Refugee arrivals in the U.S.')
# Out:
# <Axes: title={'center': 'Refugee arrivals in the U.S.'}, ylabel='arrivals'>

# %% [markdown]
# - Start by setting the index of the dataframe to the origin column. This ensures that our legend will show the country names.
# - Slice our results to show just the top 10 countries. This makes our chart more legible.
# - Next, use the .plot() method, specifying pie as the type of plot
# - Specify the y values - in our case arrivals
#
#
# # Time Series
# - Can also create time series using the Groupby method. For example, if we wanted to visualize the total number of refugees resettled in the U.S. across the 2005-2015 period, we would first create a Groupby object based on the “year” column (refer back to lesson 7 for more on Groupby objects).

# %%
# first create Groupby object based on year col
refugee_df.groupby('year')

# %% [markdown]
# Next, we can create a new variable calculating the average number of refugees being resettled over time.

# %%
# create new var calculating avg # of refugees resettling over time
total_arrivals_by_year = refugee_df.groupby('year')['arrivals'].sum()

# %% [markdown]
# Let’s break this command down:
#
# - We have two stacked methods here: .groupby() and .sum()
# - groupby('year')['arrivals']: For the Groupby object, groupby(year), we are isolating the “arrivals” column. Basically, we are asking to view the number of refugee arrivals by year.
# - .sum(): This method returns the sum of the values over the requested axis. In our case, it will calculate the total number of refugee arrivals per year.
# - We store our results in the total_arrivals_by_year variable
#
# Finally, we can add the .plot() method to create a line chart.

# %%
total_arrivals_by_year.plot(kind='line', color='orange', title="Total Number of Refugee Arrivals by Year")
# Out:
# <Axes: title={'center': 'Total Number of Refugee Arrivals by Year'}, xlabel='year'>

# %% [markdown]
# In this command, we are adding the .plot() method to request a chart, and specifying that we want a line graph with the “kind=line” parameter. We are also giving the chart a title with the “title='Total Number of Refugee Arrivals by Year'” parameter.

# %%
# Shows you all the dataframes you created
# %whos DataFrame
# Out:
# Variable                  Type         Data/Info
# ------------------------------------------------
# ref_sum_df                DataFrame                 origin  arri<...>       Colombia      1956
# refugee_california_df     DataFrame                year       or<...>n[15444 rows x 6 columns]
# refugee_df                DataFrame                 year       o<...>[121231 rows x 6 columns]
# refugee_drop_city_df      DataFrame                 year       o<...>[121231 rows x 4 columns]
# refugee_drop_iraq_df      DataFrame                 year       o<...>[103026 rows x 5 columns]
# refugee_drop_vietnam_df   DataFrame                 year       o<...>[115698 rows x 6 columns]
# refugee_iraq_df           DataFrame                 year origin <...>n[18205 rows x 5 columns]

# %%
# Write to CSV - use to_csv() method - add name, encoding, and index
refugee_df.to_csv('new_refugee1.csv', encoding='utf-8', index=False)
