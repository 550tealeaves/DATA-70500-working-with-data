# %% [markdown]
# <a href="https://colab.research.google.com/github/550tealeaves/DATA-70500-working-with-data/blob/main/Orig_DataIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You can upload a file from your computer directly into your Colab notebook rather than mounting your Google Drive and reading a file from there. This can save you the step of having to move the downloaded data file to your Google Drive, especially if you are only using the data file for a class exercise.

# %%
# !pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 24.2 MB/s eta 0:00:00
# ...

# %%
# Code block 1: Import libraries
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sb
import matplotlib.pyplot as plt
import scipy.stats as scp
from google.colab import files
import pyreadstat

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d43c450-ac23-4e70-a681-576c3a187244" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d43c450-ac23-4e70-a681-576c3a187244">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
try:
    ATP111_df = pd.read_spss('/content/ATP W111.sav', convert_categoricals=False)
    ATP111_df.info('verbose')
except:
    print('File could not be read.')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6034 entries, 0 to 6033
# Data columns (total 139 columns):
#  #    Column                      Dtype
# ---   ------                      -----
#  0    QKEY                        float64
#  1    INTERVIEW_START_W111        datetime64[ns]
#  2    INTERVIEW_END_W111          datetime64[ns]
#  3    DEVICE_TYPE_W111            float64
#  4    LANG_W111                   float64
#  5    XTABLET_W111                float64
#  6    SHOP18_W111                 float64
#  7    SHOP19_W111                 float64
#  8    METOO1_W111                 float64
#  9    METOOSUPOE_M1_W111          float64
#  10   METOOSUPOE_M2_W111          float64
#  11   METOOSUPOE_M3_W111          float64
#  12   METOOOPPOE_M1_W111          float64
#  13   METOOOPPOE_M2_W111          float64
#  14   METOOOPPOE_M3_W111          float64
#  15   ONLSHOP1_a_W111             float64
#  16   ONLSHOP1_b_W111             float64
# ...
